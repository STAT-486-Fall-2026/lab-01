# %% [markdown]
# # Lab 01: Git and uv readiness
#
# The purpose of this notebook is to confirm that this notebook is running from the uv-managed environment in this repository, not from a global Python installation. Complete every prompt, then use **Restart Kernel and Run All** before committing the notebook.

# %% [markdown]
# ## Section 1: Verify the lab environment
#
# Import `sys`, NumPy, pandas, and `matplotlib.pyplot`. Print the Python version, and the NumPy version. The executable path should include this repository's `.venv`.
#
# If it does not, stop and choose the repository `.venv` interpreter/kernel before continuing.
#
# (Hint: Look up how to print these version!)

# %%
# your code here

# %% [markdown]
# ---
#
# ## Section 2: Create and inspect a small data set
#
# Use `rng = np.random.default_rng(486)` to make two arrays of length 12: integer `study_hours` values from 1 through 10 and numeric `quiz_score` values. Create a pandas DataFrame with the columns `student`, `study_hours`, and `quiz_score`; labels such as `Student 1` through `Student 12` are fine.
#
# For the `study_hours`, use NumPy to sample from a Gaussian distribution with a mean of 5 and a standard deviation of 3. Model `quiz_score` as a linear function `quiz_score` = 3 * `study_hours` + 2 + $\epsilon$, where $\epsilon$~N(0, 2) (Here, 2 is the variance).
#
# Then:
#
# 1. Display the first five rows and summary statistics.
# 2. Add a `score_from_mean` column equal to each score minus the mean quiz score.
# 3. Display the revised DataFrame.
#
# The numbers do not need to model a real study. This is only a compact check that NumPy and pandas work in your project environment.

# %%
# your code here

# %% [markdown]
# ---
#
# ## Section 3: Filter, summarize, and visualize
#
# Using the DataFrame from Section 2:
#
# 1. Create and display a table of students whose quiz score is above the overall mean, sorted from highest to lowest score.
# 2. Print the mean quiz score for the full data set and the number of students in your filtered table.
# 3. Make a matplotlib scatterplot of `study_hours` (x-axis) versus `quiz_score` (y-axis). Include an informative title, axis labels, and `plt.show()`.
#
# This plot does not need a substantive statistical interpretation. It is evidence that your project environment can use NumPy, pandas, and matplotlib together.

# %%
# your code here

# %% [markdown]
# ---
#
# ## Section 4: Workflow check
#
# In the Markdown cell below, answer each question in one or two sentences:
#
# 1. What Python version did Section 1 print, and how does it show that the notebook used this repository's environment?
# 2. What is the difference between `pyproject.toml`, `uv.lock`, and `.venv/`?
# 3. What are the primary purposes for these three files?

# %% [markdown]
# (your response here)

# %% [markdown]
# ---
#
# ## Final check
#
# Restart the kernel and run all cells. Save the completed notebook, then follow the README instructions to commit and push it.
